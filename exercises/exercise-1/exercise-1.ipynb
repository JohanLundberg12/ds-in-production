# %%
import pandas as pd
import json
import requests
from requests.auth import HTTPBasicAuth
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk

# %% [markdown]
# # Index Functions

# %%
def create_index(es, index_name, settings=None):
    """
    Create an Elasticsearch index
    @param es: an Elasticsearch object
    @param index_name: the name of the new index to be created
    @param settings: the index settings
    @return whether the index was created
    """
    is_created = False
    try:
        if es.indices.exists(index=index_name):
            es.indices.delete(index=index_name, ignore=[404])
        es.indices.create(index=index_name, body=settings)
        is_created = True
    except Exception as ex:
        print(str(ex))
    return is_created

# %%
class Elastic:
    """
    A convenience object to send HTTP requests to Elasticsearch
    """
    def __init__(self, endpoint, username, password):
        """
        @param endpoint: the URL of the Elasticsearch instance
        @param username: the Elasticsearch username 
        @param password: the Elasticsearch password
        """
        self.header = {'Content-Type': 'application/json', 'charset':'UTF-8'}
        #self.header={'Content-Type': '--data-binary application/x-ndjson'}
        self.endpoint = endpoint
        self.username = username
        self.password = password
        self.methods_mapping = {'get': requests.get, 
                                'put':requests.put, 
                                'post':requests.post, 
                                'delete':requests.delete}
        
    def curl(self, method, handle, json=None):
        """
        Sends an HTTP request to the Elasticsearch instanc
        @param method: can be 'get', 'put', 'post', 'delete'
        @param handle: the API handle to be appended to the Elasticsearch url
        @param json: the json payload of the HTTP request
        """
        http_method = self.methods_mapping[method.lower()]
        r = http_method(f'{self.endpoint}/{handle}', auth=HTTPBasicAuth(USER, PWD), 
                        headers=self.header, json=json)
        return r

# %% [markdown]
# # Connect to ES

# %%
USER = 'elastic'
PWD = 'mypassword'
index_name = 'tesco'
ES_ENDPOINT = 'http://localhost:9200'

# %% [markdown]
# # Preparing Data

# %%
df = pd.read_csv('../../data/tesco/tesco_inventory_clean.csv')
df = df.set_index('product_id')
docs = df.to_dict(orient='records') #to json format
doc_ids = df.index

# %% [markdown]
# # Creating an index
#     mappings:
#      - I explicitly set the type of the columns category, description and ingredients to be text, the type of the
#          remaining columns is handled dynamically.
#
#     In the settings:
#      - I set the number of shards that an index should have to 8.
#      - I set the number of replicas per primary shard to 3.
#      - I set the analyzer to be a standard one using english stopwords.

# %%
# Index settings
settings_basic = {
    "mappings" : {
      "properties" : {
        "category" : {
          "type" : "text"
        },
        "description" : {
          "type" : "text"
        },
        "ingredients" : {
          "type" : "text"
        }
      }
  },
    "settings": {
        "number_of_shards": 8,
        "number_of_replicas": 3,
        "analysis": {
            "analyzer": {"std_english": {"type": "standard", "stopwords": "_english_" }}
        }
    }
}

# %% [markdown]
#     Below, I connect to my local ES node

# %%
#connect to the local elasticsearch node and authenticate
es = Elasticsearch([ES_ENDPOINT], http_auth=(USER, PWD))
#create an index
is_created = create_index(es, index_name, settings=settings_basic)
print(f'Index creation: {is_created}')
# Out:
# /home/jolu/miniconda3/envs/prod/lib/python3.10/site-packages/elasticsearch/connection/base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.16/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /tmp/ipykernel_30117/1221527122.py:13: DeprecationWarning: The 'body' parameter is deprecated for the 'create' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   es.indices.create(index=index_name, body=settings)
# Index creation: True

# %% [markdown]
#     I use the Elastic class to send HTTP requests to ES

# %%
e = Elastic(ES_ENDPOINT, USER, PWD)

# %%
# get the index details and settings
r = e.curl('get', index_name)
r.json()
# Out:
# {'tesco': {'aliases': {},
#   'mappings': {'properties': {'category': {'type': 'text'},
#     'description': {'type': 'text'},
#     'ingredients': {'type': 'text'}}},
#   'settings': {'index': {'routing': {'allocation': {'include': {'_tier_preference': 'data_content'}}},
#     'number_of_shards': '8',
#     'provided_name': 'tesco',
#     'creation_date': '1654221012191',
#     'analysis': {'analyzer': {'std_english': {'type': 'standard',
#        'stopwords': '_english_'}}},
#     'number_of_replicas': '3',
#     'uuid': '4FIve4PjScGMWKyB-bkogA',
#     'version': {'created': '7160299'}}}}}

# %% [markdown]
# # Bulk indexing
#     For efficiency

# %%
# bulk indexing (via official API)

actions = [
  {
    "_index": index_name,
    "_id": doc_id,
    "_source": doc
  }
  for doc_id, doc in list(zip(doc_ids, docs))
]

# send actions in bulk (the API takes care of chunking them optimally)
bulk(es, actions)
# Out:
# (22596, [])

# %%
# get settings info of the selected index
es.indices.get_settings(index=index_name)
# Out:
# {'tesco': {'settings': {'index': {'routing': {'allocation': {'include': {'_tier_preference': 'data_content'}}},
#     'number_of_shards': '8',
#     'provided_name': 'tesco',
#     'creation_date': '1654221012191',
#     'analysis': {'analyzer': {'std_english': {'type': 'standard',
#        'stopwords': '_english_'}}},
#     'number_of_replicas': '3',
#     'uuid': '4FIve4PjScGMWKyB-bkogA',
#     'version': {'created': '7160299'}}}}}

# %% [markdown]
#     Point #1: I used multiple shards and bulk indexing for efficiency
#     Point #2: Not taken into account.
#     Point #3: Handled in the settings basics.
#     Point #4: Handled in the mapper of the settings basics.
#     Point #5: I didn't do this.

# %% [markdown]
# # Queries

# %%
# exact match query
query = {
  "query": {
    "match_phrase": {
      "description": {
        "query": "Frijj banana milkshake"
      }
    }
  }
}
r = e.curl('get', f'tesco/_search', query)
r.json()
# Out:
# {'took': 26,
#  'timed_out': False,
#  '_shards': {'total': 8, 'successful': 8, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1, 'relation': 'eq'},
#   'max_score': 21.523006,
#   'hits': [{'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '51665765',
#     '_score': 21.523006,
#     '_source': {'category': 'dairy',
#      'description': 'Frijj Banana Milkshake 471Ml',
#      'ingredients': '0.8% Fat <strong>Milk</strong> (94%) Sugar <strong>Buttermilk</strong> Powder Banana Flavouring Stabilisers (Carrageenan, Cellulose Gum) Colour (Carotenes)',
#      'energy': 64.0,
#      'fat': 1.0,
#      'saturates': 0.6,
#      'salt': 0.2,
#      'sugars': 9.8,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 1.3}}]}}

# %% [markdown]
#     Point #7: I define a match query above on the description field.

# %%
# Full text query, multiple fields
query = {
"query": {
    "multi_match": {
            "query": "milk",
            "type": "most_fields",
            "fields": ["description^2", "ingredients"]
        }
    }
}
r = e.curl('get', f'tesco/_search', query)
r.json()
# Out:
# {'took': 37,
#  'timed_out': False,
#  '_shards': {'total': 8, 'successful': 8, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 7076, 'relation': 'eq'},
#   'max_score': 12.30955,
#   'hits': [{'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '70582338',
#     '_score': 12.30955,
#     '_source': {'category': 'sweets',
#      'description': 'Aero Medium Milk Bubbly Milk Bar 40G',
#      'ingredients': 'Sugar Dried Whole <strong>Milk</strong> Cocoa Mass Cocoa Butter Vegetable Fat (Palm/Shea/Illipe/Mango Kernel/Kokum Gurgi/Sal) Lactose and Proteins from Whey (from <strong>Milk</strong>) Whey Powder (from <strong>Milk</strong>) Emulsifier (Sunflower Lecithin) Flavouring Milk Chocolate contains Cocoa Solids 25% minimum Milk Solids 14% minimum and Vegetable Fat in addition to Cocoa Butter',
#      'energy': 542.0,
#      'fat': 30.9,
#      'saturates': 18.0,
#      'salt': 0.2,
#      'sugars': 56.2,
#      'protein': 6.5,
#      'carbohydrate': 57.8,
#      'fibre': 2.2,
#      'avg_price': 0.6}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '63761362',
#     '_score': 11.7485485,
#     '_source': {'category': 'sweets',
#      'description': 'Mikado Milk 75G',
#      'ingredients': '<strong>Wheat</strong> Flour  Sugar Cocoa Butter Cocoa Mass Skimmed <strong>Milk</strong> Powder Vegetable Fats (Palm, Coconut) Glucose Syrup <strong>Milk</strong> Fat Whey Powder (from <strong>Milk</strong>) Salt Emulsifier (<strong>Soya</strong> Lecithin) Raising Agent (E503) Yeast Flavouring',
#      'energy': 480.0,
#      'fat': 19.5,
#      'saturates': 11.5,
#      'salt': 0.7,
#      'sugars': 35.0,
#      'protein': 6.8,
#      'carbohydrate': 68.0,
#      'fibre': 3.1,
#      'avg_price': 1.39}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '64875709',
#     '_score': 11.108377,
#     '_source': {'category': 'dairy',
#      'description': 'Farmlea Condensed Milk 397G',
#      'ingredients': 'Whole Cows <strong>Milk</strong> Sugar Cows <strong>Milk</strong> (Skimmed) Minimum 8% Milk Fat, 20% Milk solids not Fat',
#      'energy': 325.0,
#      'fat': 8.0,
#      'saturates': 5.4,
#      'salt': 0.23,
#      'sugars': 56.4,
#      'protein': 6.9,
#      'carbohydrate': 56.4,
#      'fibre': 0.0,
#      'avg_price': 1.57}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '50031296',
#     '_score': 11.019591,
#     '_source': {'category': 'dairy',
#      'description': 'Carnation Evaporated Milk 410G',
#      'ingredients': 'Whole <strong>Milk</strong> Stabiliser (Sodium Phosphates) Vitamin D Minimum 9% Milk Fat, 22% Milk Solids Not Fat',
#      'energy': 160.0,
#      'fat': 9.0,
#      'saturates': 6.1,
#      'salt': 0.33,
#      'sugars': 12.0,
#      'protein': 7.7,
#      'carbohydrate': 12.0,
#      'fibre': 0.0,
#      'avg_price': 1.1}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '68173203',
#     '_score': 10.855521,
#     '_source': {'category': 'dairy',
#      'description': 'Just Milk Longlife Skimmed Milk 6X1l',
#      'ingredients': 'no_ingredients',
#      'energy': 32.0,
#      'fat': 0.1,
#      'saturates': 0.0,
#      'salt': 0.1,
#      'sugars': 4.8,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 4.99}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '58711314',
#     '_score': 10.836706,
#     '_source': {'category': 'sweets',
#      'description': 'Kinnerton Milk Chocolate Lolly',
#      'ingredients': 'Cocoa Butter Dried Whole <strong>Milk</strong> Cocoa Mass Dried Whey (<strong>Milk</strong>) Vegetable Fat (Palm Kernel, Shea, Sal, Mango Kernel, Illipe, Kokum Gurgi in varying portions) Emulsifiers (<strong>Soya</strong> Lecithin, Polyglycerol Polyricinoleate) Vanilla Flavouring Contains Vegetable Fat in addition to Cocoa Butter Cocoa Solids 25% minimum, Milk Solids 14% minimum',
#      'energy': 0.0,
#      'fat': 0.0,
#      'saturates': 0.0,
#      'salt': 0.0,
#      'sugars': 0.0,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 0.65}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '51465679',
#     '_score': 10.800214,
#     '_source': {'category': 'sweets',
#      'description': 'Toblerone Milk Chocolate 400G',
#      'ingredients': 'Sugar Whole <strong>Milk</strong> Powder Cocoa Butter Cocoa Mass Honey (3.0%) <strong>Milk</strong> Fat <strong>Almonds</strong> (1.6%) Emulsifier (<strong>Soya</strong> Lecithin) <strong>Egg</strong> White Flavouring Milk Chocolate: Cocoa Solids 28% Milk Solids 14% minimum',
#      'energy': 535.0,
#      'fat': 29.5,
#      'saturates': 18.0,
#      'salt': 0.15,
#      'sugars': 59.5,
#      'protein': 5.6,
#      'carbohydrate': 60.5,
#      'fibre': 2.2,
#      'avg_price': 4.0}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '54310115',
#     '_score': 10.775324,
#     '_source': {'category': 'sweets',
#      'description': 'Galaxy Milk Chocolate 42G',
#      'ingredients': 'Sugar Cocoa Butter Skimmed <strong>Milk</strong> Powder Cocoa Mass <strong>Milk</strong> Fat <strong>Lactose</strong> Whey Powder (from <strong>Milk</strong>) Palm Fat Emulsifier (<strong>Soya</strong> Lecithin) Natural Vanilla Extract Milk Chocolate contains Milk Solids 14% minimum and Cocoa Solids 25% minimum Milk Chocolate contains Vegetable Fats in addition to Cocoa Butter',
#      'energy': 546.0,
#      'fat': 32.4,
#      'saturates': 19.6,
#      'salt': 0.25,
#      'sugars': 55.4,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 0.6}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '50342688',
#     '_score': 10.756997,
#     '_source': {'category': 'sweets',
#      'description': 'Toblerone Milk Chocolate 100G',
#      'ingredients': 'Sugar Whole <strong>Milk</strong> Powder Cocoa Butter Cocoa Mass Honey (3.0%) <strong>Milk</strong> Fat <strong>Almonds</strong> (1.6%) Emulsifier (<strong>Soya</strong> Lecithin) <strong>Egg</strong> White Flavouring Milk Chocolate: Cocoa Solids 28% minimum Milk Solids 14% minimum',
#      'energy': 535.0,
#      'fat': 29.5,
#      'saturates': 18.0,
#      'salt': 0.15,
#      'sugars': 59.5,
#      'protein': 5.6,
#      'carbohydrate': 60.5,
#      'fibre': 2.2,
#      'avg_price': 1.645}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '67929441',
#     '_score': 10.6011,
#     '_source': {'category': 'dairy',
#      'description': 'Tesco Strawberry Milk 330Ml',
#      'ingredients': 'Semi Skimmed <strong>Milk</strong> (94%) Sugar Skimmed <strong>Milk </strong>Powder Concentrated Strawberry Juice Stabilisers (Carrageenan, Xanthan Gum) Flavouring Colour (Beetroot Red)',
#      'energy': 70.0,
#      'fat': 1.7,
#      'saturates': 1.1,
#      'salt': 0.1,
#      'sugars': 9.7,
#      'protein': 3.8,
#      'carbohydrate': 9.8,
#      'fibre': 0.1,
#      'avg_price': 0.6}}]}}

# %% [markdown]
#     Point #8: I define a multi-match query above on description and ingredients, boosting description by a factor of 2.

# %%
# full-text query
query = {
  "query": {
    "bool": {
      "must": {
        "multi_match": {
          "query": "milk",
          "fields": [
            "description",
            "ingredients"
          ],
          "type": "best_fields"
        }
      },
      "filter": {
        "term": {
          "category": "sweets"
        }
      }
    }
  }
}
r = e.curl('get', f'tesco/_search', query)
r.json()
# Out:
# {'took': 16,
#  'timed_out': False,
#  '_shards': {'total': 8, 'successful': 8, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 2675, 'relation': 'eq'},
#   'max_score': 5.181798,
#   'hits': [{'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '70582338',
#     '_score': 5.181798,
#     '_source': {'category': 'sweets',
#      'description': 'Aero Medium Milk Bubbly Milk Bar 40G',
#      'ingredients': 'Sugar Dried Whole <strong>Milk</strong> Cocoa Mass Cocoa Butter Vegetable Fat (Palm/Shea/Illipe/Mango Kernel/Kokum Gurgi/Sal) Lactose and Proteins from Whey (from <strong>Milk</strong>) Whey Powder (from <strong>Milk</strong>) Emulsifier (Sunflower Lecithin) Flavouring Milk Chocolate contains Cocoa Solids 25% minimum Milk Solids 14% minimum and Vegetable Fat in addition to Cocoa Butter',
#      'energy': 542.0,
#      'fat': 30.9,
#      'saturates': 18.0,
#      'salt': 0.2,
#      'sugars': 56.2,
#      'protein': 6.5,
#      'carbohydrate': 57.8,
#      'fibre': 2.2,
#      'avg_price': 0.6}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '63761362',
#     '_score': 4.964626,
#     '_source': {'category': 'sweets',
#      'description': 'Mikado Milk 75G',
#      'ingredients': '<strong>Wheat</strong> Flour  Sugar Cocoa Butter Cocoa Mass Skimmed <strong>Milk</strong> Powder Vegetable Fats (Palm, Coconut) Glucose Syrup <strong>Milk</strong> Fat Whey Powder (from <strong>Milk</strong>) Salt Emulsifier (<strong>Soya</strong> Lecithin) Raising Agent (E503) Yeast Flavouring',
#      'energy': 480.0,
#      'fat': 19.5,
#      'saturates': 11.5,
#      'salt': 0.7,
#      'sugars': 35.0,
#      'protein': 6.8,
#      'carbohydrate': 68.0,
#      'fibre': 3.1,
#      'avg_price': 1.39}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '58711314',
#     '_score': 4.5679746,
#     '_source': {'category': 'sweets',
#      'description': 'Kinnerton Milk Chocolate Lolly',
#      'ingredients': 'Cocoa Butter Dried Whole <strong>Milk</strong> Cocoa Mass Dried Whey (<strong>Milk</strong>) Vegetable Fat (Palm Kernel, Shea, Sal, Mango Kernel, Illipe, Kokum Gurgi in varying portions) Emulsifiers (<strong>Soya</strong> Lecithin, Polyglycerol Polyricinoleate) Vanilla Flavouring Contains Vegetable Fat in addition to Cocoa Butter Cocoa Solids 25% minimum, Milk Solids 14% minimum',
#      'energy': 0.0,
#      'fat': 0.0,
#      'saturates': 0.0,
#      'salt': 0.0,
#      'sugars': 0.0,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 0.65}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '51465679',
#     '_score': 4.4141436,
#     '_source': {'category': 'sweets',
#      'description': 'Toblerone Milk Chocolate 400G',
#      'ingredients': 'Sugar Whole <strong>Milk</strong> Powder Cocoa Butter Cocoa Mass Honey (3.0%) <strong>Milk</strong> Fat <strong>Almonds</strong> (1.6%) Emulsifier (<strong>Soya</strong> Lecithin) <strong>Egg</strong> White Flavouring Milk Chocolate: Cocoa Solids 28% Milk Solids 14% minimum',
#      'energy': 535.0,
#      'fat': 29.5,
#      'saturates': 18.0,
#      'salt': 0.15,
#      'sugars': 59.5,
#      'protein': 5.6,
#      'carbohydrate': 60.5,
#      'fibre': 2.2,
#      'avg_price': 4.0}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '70482024',
#     '_score': 4.39365,
#     '_source': {'category': 'sweets',
#      'description': 'Tesco Milk Bottles 75G',
#      'ingredients': 'Glucose Syrup Sugar Dextrose Pork Gelatine Flavouring Sunflower Oil Glazing Agent (White and Yellow Beeswax) Dried Skimmed <strong>Milk</strong> Salt',
#      'energy': 335.0,
#      'fat': 0.2,
#      'saturates': 0.1,
#      'salt': 0.1,
#      'sugars': 52.0,
#      'protein': 6.3,
#      'carbohydrate': 77.0,
#      'fibre': 0.0,
#      'avg_price': 0.45}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '54310115',
#     '_score': 4.390726,
#     '_source': {'category': 'sweets',
#      'description': 'Galaxy Milk Chocolate 42G',
#      'ingredients': 'Sugar Cocoa Butter Skimmed <strong>Milk</strong> Powder Cocoa Mass <strong>Milk</strong> Fat <strong>Lactose</strong> Whey Powder (from <strong>Milk</strong>) Palm Fat Emulsifier (<strong>Soya</strong> Lecithin) Natural Vanilla Extract Milk Chocolate contains Milk Solids 14% minimum and Cocoa Solids 25% minimum Milk Chocolate contains Vegetable Fats in addition to Cocoa Butter',
#      'energy': 546.0,
#      'fat': 32.4,
#      'saturates': 19.6,
#      'salt': 0.25,
#      'sugars': 55.4,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 0.6}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '50342688',
#     '_score': 4.3841,
#     '_source': {'category': 'sweets',
#      'description': 'Toblerone Milk Chocolate 100G',
#      'ingredients': 'Sugar Whole <strong>Milk</strong> Powder Cocoa Butter Cocoa Mass Honey (3.0%) <strong>Milk</strong> Fat <strong>Almonds</strong> (1.6%) Emulsifier (<strong>Soya</strong> Lecithin) <strong>Egg</strong> White Flavouring Milk Chocolate: Cocoa Solids 28% minimum Milk Solids 14% minimum',
#      'energy': 535.0,
#      'fat': 29.5,
#      'saturates': 18.0,
#      'salt': 0.15,
#      'sugars': 59.5,
#      'protein': 5.6,
#      'carbohydrate': 60.5,
#      'fibre': 2.2,
#      'avg_price': 1.645}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '54231076',
#     '_score': 4.2701817,
#     '_source': {'category': 'sweets',
#      'description': 'Cadbury Dairy Milk 110G',
#      'ingredients': '<strong>Milk</strong>** Sugar Cocoa Butter Cocoa Mass Vegetable Fats (Palm, Shea) Emulsifiers (E442, E476) Flavourings Cocoa, Sugar: Traded in compliance with Fairtrade Standards, total 70% **The equivalent of 426ml of Fresh Liquid Milk in every 227g of Milk Chocolate Milk Solids 20% minimum, actual 23% Cocoa Solids 20% minimum Contains Vegetable Fats in addition to Cocoa Butter',
#      'energy': 530.0,
#      'fat': 30.5,
#      'saturates': 18.5,
#      'salt': 0.23,
#      'sugars': 56.0,
#      'protein': 7.5,
#      'carbohydrate': 56.5,
#      'fibre': 0.7,
#      'avg_price': 1.17}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '70761081',
#     '_score': 4.2300158,
#     '_source': {'category': 'sweets',
#      'description': 'Yorkie Milk Multi Pack 138G',
#      'ingredients': 'Sugar Dried Whole <strong>Milk</strong> Cocoa Butter Cocoa Mass Vegetable Fat (from Palm/Shea/Sal/Illipe/Kokum Gurgi/Mango Kernel) Lactose and Proteins from Whey (from <strong>Milk</strong>) Whey Powder (from <strong>Milk</strong>) Butterfat (from <strong>Milk</strong>) Emulsifier (Sunflower Lecithin) Milk Chocolate contains Cocoa Solids 25% minimum, Milk Solids 14% minimum and Vegetable Fat in addition to Cocoa Butter',
#      'energy': 540.0,
#      'fat': 30.5,
#      'saturates': 17.3,
#      'salt': 0.2,
#      'sugars': 58.7,
#      'protein': 5.8,
#      'carbohydrate': 59.8,
#      'fibre': 1.7,
#      'avg_price': 2.25}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '54231646',
#     '_score': 4.2300158,
#     '_source': {'category': 'sweets',
#      'description': 'Cadbury Dairy Milk Bar 53G',
#      'ingredients': 'Milk** Sugar Cocoa Butter Cocoa Mass Vegetable Fat Emulsifiers (E442, E476) Flavourings **The equivalent of 426ml of fresh liquid milk in every 227g of milk chocolate Milk Solids 20% minimum, actual 23% Cocoa Solids 20% minimum Contains Vegetable Fats in addition to Cocoa Butter',
#      'energy': 530.0,
#      'fat': 30.0,
#      'saturates': 18.5,
#      'salt': 0.28,
#      'sugars': 56.0,
#      'protein': 8.4,
#      'carbohydrate': 56.5,
#      'fibre': 0.7,
#      'avg_price': 1.07}}]}}

# %% [markdown]
#     Point #9: Same as 8 but I added a filter on category, in this case filtering by "sweets".

# %%
query ={
  "query": {
    "fuzzy": {
      "ingredients": {
        "value": "milk",
        "fuzziness": "AUTO",
        "max_expansions": 50,
        "prefix_length": 0,
        "transpositions": True,
        "rewrite": "constant_score"
      }
    }
  }
}
r = e.curl('get', f'tesco/_search', query)
r.json()
# Out:
# {'took': 30,
#  'timed_out': False,
#  '_shards': {'total': 8, 'successful': 8, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 6906, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '62069816',
#     '_score': 1.0,
#     '_source': {'category': 'grains',
#      'description': 'Tesco 6 Garlic And Coriander Mini Naan Bread 300G',
#      'ingredients': 'Wheat Flour (<strong>Wheat</strong> Flour, Calcium Carbonate, Iron, Niacin, Thiamin) Water Rapeseed Oil Sugar Yeast Spirit Vinegar Kalonji Seeds Raising Agents (Disodium Diphosphate, Sodium Bicarbonate, Calcium Phosphate) Garlic (0.8%) Dried Parsley Salt Flavouring Preservative (Calcium Propionate) Dried Skimmed <strong>Milk</strong> Ground Coriander',
#      'energy': 254.0,
#      'fat': 3.5,
#      'saturates': 0.3,
#      'salt': 0.7,
#      'sugars': 4.3,
#      'protein': 7.4,
#      'carbohydrate': 46.6,
#      'fibre': 3.4,
#      'avg_price': 1.275}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '76722844',
#     '_score': 1.0,
#     '_source': {'category': 'fruit_veg',
#      'description': 'Tesco Finest Chicken Chardonnay Wine And Tarragon Soup 600G',
#      'ingredients': 'Chicken Stock Potato Single Cream (<strong>Milk</strong>) Cooked British Chicken (6%) Onion Chardonnay White Wine (2%) Cornflour Butter (<strong>Milk</strong>) Potato Starch Roast Garlic Purée Tarragon Sage Bay Leaf Thyme Black Pepper Turmeric Chicken Stock contains: Water Concentrated Chicken Juices (Chicken Skin, Chicken, Water, Chicken Fat) Sugar Salt Cornflour Onion Concentrate',
#      'energy': 57.0,
#      'fat': 3.2,
#      'saturates': 1.9,
#      'salt': 0.6,
#      'sugars': 0.4,
#      'protein': 3.1,
#      'carbohydrate': 3.7,
#      'fibre': 0.3,
#      'avg_price': 2.4}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '67439698',
#     '_score': 1.0,
#     '_source': {'category': 'sweets',
#      'description': 'Tesco Swirly Strawberry Cheesecake 120G',
#      'ingredients': 'Full Fat Soft Cheese (Milk) (contains Salt) Water Sugar Cream (Milk) Wheat Flour Strawberry Purée (6%) Butter (Milk) Lemon Juice Cornflour White Chocolate (Sugar, Cocoa Butter, Dried Whole Milk, Dried Skimmed Milk, Emulsifier (Soya Lecithins), Flavouring) Demerara Sugar Rapeseed Oil Concentrated Lemon Juice Palm Oil Stabiliser (Pectin) Shea Fat Acidity Regulator (Sodium Citrate) Golden Syrup Colours (Anthocyanins, Paprika Extract) Tapioca Starch Firming Agent (Calcium Lactate) Raising Agents (Ammonium Bicarbonate, Sodium Bicarbonate) Salt Glazing Agent (Acacia) Sucrose Honey Emulsifier (Sunflower Lecithins)',
#      'energy': 316.0,
#      'fat': 19.7,
#      'saturates': 11.5,
#      'salt': 0.3,
#      'sugars': 21.3,
#      'protein': 3.0,
#      'carbohydrate': 31.0,
#      'fibre': 1.3,
#      'avg_price': 1.0}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '61801083',
#     '_score': 1.0,
#     '_source': {'category': 'sweets',
#      'description': 'Cadbury Fingers Milk Chocolate 171G',
#      'ingredients': '<strong>Milk</strong> Chocolate (48%) (<strong>Milk</strong>, Sugar, Cocoa Butter, Cocoa Mass, Vegetable Fats (Palm, Sal and Shea, in varying proportions) Emulsifiers (<strong>Soya</strong> Lecithin, E476), Flavourings) <strong>Wheat</strong> Flour (with Added Calcium, Iron, Niacin and Thiamin) Palm Oil Sugar Partially Inverted Sugar Syrup Salt Raising Agents (Ammonium Bicarbonate, Sodium Bicarbonate) Flavouring',
#      'energy': 516.0,
#      'fat': 27.1,
#      'saturates': 14.8,
#      'salt': 0.4,
#      'sugars': 30.5,
#      'protein': 7.3,
#      'carbohydrate': 60.0,
#      'fibre': 1.5,
#      'avg_price': 1.99}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '71934653',
#     '_score': 1.0,
#     '_source': {'category': 'readymade',
#      'description': 'Cadbury Snack Sandwich 12S 312G',
#      'ingredients': 'Sugar <strong>Milk</strong> <strong>Wheat</strong> Flour Vegetable Fats (Palm, Shea, Sal) Cocoa Butter Cocoa Mass Dextrose Fat Reduced Cocoa Invert Sugar Syrup Emulsifiers (<strong>Soya</strong> Lecithin, E476) <strong>Barley</strong> Malt Syrup Salt Vegetable Oil (Rapeseed) Raising Agents (Sodium Bicarbonate) Flavouring',
#      'energy': 460.0,
#      'fat': 25.5,
#      'saturates': 15.5,
#      'salt': 0.43,
#      'sugars': 38.5,
#      'protein': 5.8,
#      'carbohydrate': 52.0,
#      'fibre': 0.7,
#      'avg_price': 3.0}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '75981209',
#     '_score': 1.0,
#     '_source': {'category': 'grains',
#      'description': 'Quaker Oat So Simple Multigrain Original Porridge 50G',
#      'ingredients': 'Quaker <strong><strong>Oat</strong>s</strong> (44%) (Rolled <strong><strong>Oat</strong>s</strong>, <strong>Oat</strong> Flavour) <strong>Rye</strong> (19%) <strong>Barley</strong> (14%) Skimmed <strong>Milk</strong> Powder Sugar <strong>Cream</strong> Powder',
#      'energy': 367.0,
#      'fat': 4.5,
#      'saturates': 1.2,
#      'salt': 0.19,
#      'sugars': 20.3,
#      'protein': 12.1,
#      'carbohydrate': 65.0,
#      'fibre': 8.9,
#      'avg_price': 0.99}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '77454157',
#     '_score': 1.0,
#     '_source': {'category': 'meat_red',
#      'description': 'Tahira 12 Halal Chicken And Beef Burgers 780G',
#      'ingredients': 'Mechanically Separated Chicken 51%* Water Beef Fat 16%* Breadcrumbs (<strong><strong>Wheat</strong> Flour</strong>, Sugar, Yeast, Glucose Syrup, Vegetable Oils (Palm, Rapeseed) Emulsifiers: E433, E470a, <strong>Soy Lecithin</strong>, Salt, <strong>Rye Flour</strong>, <strong>Free-Range <strong>Eggs</strong></strong>, <strong>Whole Grain <strong>Oat Flour</strong></strong>, Maize Flour, Vegetable Fibers (<strong>Wheat</strong>, Inulin)) Salt Spices Onions Stabilizers: E451, E450 Flavor Enhancer: E621 Fermented Rice <strong><strong>Milk</strong> Sugar</strong> Hydrolyzed <strong>Soy Protein</strong> Antioxidant: E361 *Products slaughtered according to Islamic rituals',
#      'energy': 0.0,
#      'fat': 0.0,
#      'saturates': 0.0,
#      'salt': 0.0,
#      'sugars': 0.0,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 4.25}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '60876640',
#     '_score': 1.0,
#     '_source': {'category': 'sweets',
#      'description': 'Tesco Rice Cakes Mild Chilli135g',
#      'ingredients': 'Brown Rice (53%) Maize (35%) Mild Chilli Seasoning Mild Chilli Seasoning contains: <strong>Milk</strong> Sugar Salt Fructose Spices (Chilli Pepper, Cayenne Pepper, Jalape&#241 o Chilli, Cumin) Onion Powder Garlic Powder Yeast Extract Flavouring Citric Acid',
#      'energy': 369.0,
#      'fat': 2.5,
#      'saturates': 0.6,
#      'salt': 2.3,
#      'sugars': 5.9,
#      'protein': 7.2,
#      'carbohydrate': 78.1,
#      'fibre': 2.4,
#      'avg_price': 2.15}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '50907286',
#     '_score': 1.0,
#     '_source': {'category': 'tea_coffee',
#      'description': 'Typhoo Q T Instant White Tea 150G',
#      'ingredients': 'Whitener (42%) (Coconut Oil, Dried Glucose Syrup, Stabilisers (E340ii, E452i), <strong>Milk</strong> Proteins, Emulsifier (E471), Anti-Caking Agent (E551)) Whey Permeate (from <strong>Milk</strong>) Dried Glucose Syrup Soluble Solids of Tea (13%) Stabiliser (E451) Skimmed <strong>Milk</strong> Powder Flavouring',
#      'energy': 457.0,
#      'fat': 25.4,
#      'saturates': 22.9,
#      'salt': 2.5,
#      'sugars': 31.2,
#      'protein': 5.6,
#      'carbohydrate': 51.4,
#      'fibre': 0.0,
#      'avg_price': 2.45}},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '77407393',
#     '_score': 1.0,
#     '_source': {'category': 'sweets',
#      'description': 'Lindt Hello Nougat Crunch Bar 100G',
#      'ingredients': 'Sugar Cocoa Butter Whole <strong>Milk</strong> Powder <strong>Hazelnuts</strong> (12%) Cocoa Mass Skim <strong>Milk</strong> Powder Anhydrous <strong>Milk</strong> Fat <strong>Wheat</strong> Flour Emulsifier (<strong>Soya</strong> Lecithin) <strong>Lactose</strong> Salt Flavouring Vanillin Vegetable Fat (Palm, Coconut) <strong>Barley</strong> Malt Extract Caramel Sugar Syrup Raising Agent (Sodium Hydrogen Carbonate) Milk Chocolate contains: Cocoa Solids: 30% min., Milk Solids: 14% min.',
#      'energy': 552.0,
#      'fat': 35.0,
#      'saturates': 17.0,
#      'salt': 0.2,
#      'sugars': 49.0,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 1.89}}]}}

# %%
# full-text query
query = {
    "query": {
        "match": {
            "description": {
                "query": "milk"
            }
        }
    },
   "sort" : [
      {"avg_price" : {"order" : "desc"}}
   ]
}
r = e.curl('get', f'tesco/_search', query)
r.json()
# Out:
# {'took': 38,
#  'timed_out': False,
#  '_shards': {'total': 8, 'successful': 8, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 504, 'relation': 'eq'},
#   'max_score': None,
#   'hits': [{'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '76098401',
#     '_score': None,
#     '_source': {'category': 'dairy',
#      'description': 'Alpro Longlife Unsweetened Soya Milk Alternative 6 X 1 Litre',
#      'ingredients': 'Water Hulled <strong>Soya</strong> Beans (6.5%) Acidity Regulators (Monopotassium Phosphate, Dipotassium Phosphate) Calcium (Calcium Carbonate) Maltodextrin Stabiliser (Gellan Gum) Vitamins (Riboflavin (B2), B12, D2)',
#      'energy': 32.0,
#      'fat': 1.8,
#      'saturates': 0.3,
#      'salt': 0.03,
#      'sugars': 0.1,
#      'protein': 3.3,
#      'carbohydrate': 0.2,
#      'fibre': 0.6,
#      'avg_price': 7.49},
#     'sort': [7.49]},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '59726704',
#     '_score': None,
#     '_source': {'category': 'sweets',
#      'description': 'Lindt Lindor Milk Chocolate Truffles Carton 337G',
#      'ingredients': 'Sugar Vegetable Fats (Coconut, Palm Kernel) Cocoa Butter Cocoa Mass Whole <strong>Milk</strong> Powder Skimmed <strong>Milk</strong> Powder <strong>Lactose</strong> Anhydrous <strong>Milk</strong> Fat Emulsifier (<strong>Soya</strong> Lecithin) <strong>Barley</strong> Malt Extract Flavourings Vanilla Milk Chocolate contains - Cocoa solids: 31% minimum, Milk solids: 20% minimum',
#      'energy': 620.0,
#      'fat': 48.0,
#      'saturates': 34.0,
#      'salt': 0.15,
#      'sugars': 40.0,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 7.0},
#     'sort': [7.0]},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '50082298',
#     '_score': None,
#     '_source': {'category': 'sweets',
#      'description': 'Cadbury Milk Tray Boxed Chocolates 360G',
#      'ingredients': 'Sugar Vegetable Fats (Palm, Shea) Cocoa Butter Glucose Syrup Cocoa Mass Dried Skimmed <strong>Milk</strong> Dried Whey (from <strong>Milk</strong>) <strong>Milk</strong> Fat Invert Sugar Syrup <strong>Hazelnuts</strong> Emulsifiers (E442, <strong>Soya</strong> Lecithin, E471, Sunflower Lecithin) Fat-Reduced Cocoa Powder Dried Whole <strong>Milk</strong> Humectant (Sorbitol Syrup) Salt Strawberry Powder Flavourings Molasses  Sodium Bicarbonate Citric Acid Caramelised Sugar Cinnamon  Stabiliser (Invertase) Milk Chocolate: Milk Solids 14% minimum Milk Chocolate and White Chocolate contain Vegetable Fats in addition to Cocoa Butter',
#      'energy': 515.0,
#      'fat': 27.5,
#      'saturates': 15.5,
#      'salt': 0.38,
#      'sugars': 56.5,
#      'protein': 4.1,
#      'carbohydrate': 61.5,
#      'fibre': 1.6,
#      'avg_price': 7.0},
#     'sort': [7.0]},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '67129253',
#     '_score': None,
#     '_source': {'category': 'sweets',
#      'description': 'Thorntons Classics Milk Chocolates Box 274G',
#      'ingredients': 'Sugar Dried Whole <strong>Milk</strong> Cocoa Butter Cocoa Mass Glucose Syrup Palm Kernel Oil Coconut Oil <strong>Hazelnuts</strong> Lactose (<strong>Milk</strong>) Sweetened Condensed <strong>Milk</strong> (Whole <strong>Milk</strong>, Sugar) Butter (<strong>Milk</strong>) Dried Skimmed <strong>Milk</strong> Double Cream (<strong>Milk</strong>) <strong>Milk</strong> Fat Dextrose Fat Reduced Cocoa Powder Humectant (Sorbitol) Whole <strong>Milk</strong> Emulsifiers (<strong>Soya</strong> Lecithin, E471, Sunflower Lecithin) Rice Flour <strong>Almonds</strong> Maize Flour Invert Sugar Syrup Flavourings Single Cream (<strong>Milk</strong>) Maize Starch Ground Coffee Freeze-Dried Instant Coffee Gelling Agent (Pectin) Freeze-Dried Strawberry Powder  Orange Peel Salt Acid (Citric Acid) Glucose-Fructose Syrup Colour (Anthocyanins) Acidity Regulator (Sodium Citrate) Palm Oil Stabiliser (Invertase) Dried <strong>Egg</strong> White Margarine (Palm Oil, Rapeseed Oil, Water, Flavouring, Vitamin A, Vitamin D) Raising Agent (Sodium Bicarbonate) <strong>Milk</strong> Protein Milk Chocolate contains: Cocoa Solids 30% minimum, Milk Solids 20% minimum Dark Chocolate contains: Cocoa Solids 60% minimum',
#      'energy': 505.0,
#      'fat': 27.0,
#      'saturates': 17.0,
#      'salt': 0.21,
#      'sugars': 55.0,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 6.0},
#     'sort': [6.0]},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '65572277',
#     '_score': None,
#     '_source': {'category': 'sweets',
#      'description': 'Green & Blacks Milk And White Mini Chocolate Bars 12 Pack 180G',
#      'ingredients': 'Organic <strong>Milk</strong> Chocolate: Raw Cane Sugar #, Whole <strong>Milk</strong> Powder #, Cocoa Mass #, Cocoa Butter #, Emulsifier (<strong>Soya</strong> Lecithin), Vanilla Extract #, May contain <strong>Nuts</strong>, # = Certified Organic, Organic <strong>Milk</strong> Chocolate: minimum Cocoa Solids 37%, minimum <strong>Milk</strong> Solids 24%, Cocoa, Sugar, Vanilla: traded in compliance with Fairtrade Standards, total 74%† Organic <strong><strong>Milk</strong></strong> Chocolate with Butterscotch Pieces: Raw Cane Sugar #, Whole <strong><strong>Milk</strong></strong> Powder #, Cocoa Mass #, Cocoa Butter #, Butterscotch # (10%) (Raw Cane Sugar #, Glucose Syrup #, Butter (from <strong><strong>Milk</strong></strong>) #, Palm Oil #, Molasses #, Natural Flavouring), Emulsifier (<strong>Soya</strong> Lecithin), Vanilla Extract #, May contain <strong>Nuts</strong>, # = Certified Organic, Organic <strong><strong>Milk</strong></strong> chocolate: minimum Cocoa Solids 37%, minimum <strong><strong>Milk</strong></strong> Solids 24%, Cocoa, Sugar, Molasses, vanilla: traded in compliance with Fairtrade Standards, total 72%† Organic <strong>Milk</strong> Chocolate with Anglesey Sea Salt: Raw Cane Sugar #, Whole <strong>Milk</strong> Powder #, Cocoa Mass #, Cocoa Butter #, Anglesey Sea Salt (0.7%), Emulsifier (<strong>Soya</strong> Lecithin), Vanilla Extract #, May contain <strong>Nuts</strong>, # = Certified Organic, Organic <strong>Milk</strong> Chocolate: minimum Cocoa Solids 37%, minimum <strong>Milk</strong> Solids 24%, Cocoa, Sugar, Vanilla: traded in compliance with Fairtrade Standards, total 73%† Organic <strong>Milk</strong> chocolate with Raisins & <strong>Hazelnuts</strong>: Raw Cane Sugar #, Whole <strong>Milk</strong> Powder #, Cocoa Mass #, Cocoa Butter #, Raisins # (12%) (Raisins #, Palm Oil #), Chopped Roasted <strong>Hazelnuts</strong> # (8%), Emulsifier (<strong>Soya</strong> Lecithin), Vanilla Extract #, May contain other <strong>Nuts</strong>, # = Certified Organic, Organic <strong>Milk</strong> Chocolate: minimum Cocoa Solids 37%, minimum <strong>Milk</strong> Solids 24%, Cocoa, Sugar, Vanilla: traded in compliance with Fairtrade Standards, total 59%† Organic White Chocolate: Raw Cane Sugar #, Cocoa Butter #, Whole <strong>Milk</strong> Powder #, Emulsifier (<strong>Soya</strong> Lecithin), Vanilla Pod #, Vanilla Extract #, May contain <strong>Nuts</strong>, # = Certified Organic, Organic White Chocolate: minimum Cocoa Solids 30%, minimum <strong>Milk</strong> Solids 26%, Cocoa, Sugar, Vanilla: traded in compliance with Fairtrade Standards, total 71%† Organic <strong>Milk</strong> Chocolate with Chopped <strong>Almonds</strong>: Raw Cane Sugar #, Chopped Roasted <strong>Almonds</strong> # (23%), Whole <strong>Milk</strong> Powder #, Cocoa Mass #, Cocoa Butter #, Emulsifier (<strong>Soya</strong> Lecithin), Vanilla Extract #, May contain other <strong>Nuts</strong>, # = Certified Organic, Organic <strong>Milk</strong> Chocolate: minimum Cocoa Solids 37%, minimum <strong>Milk</strong> Solids 24%, Cocoa, Sugar, Vanilla: traded in compliance with Fairtrade Standards, total 57%† †Fairtrade means fairer trading conditions and opportunities for producers in developing countries to invest in their businesses and communities for a sustainable future. ',
#      'energy': 565.0,
#      'fat': 36.5,
#      'saturates': 20.5,
#      'salt': 0.3,
#      'sugars': 45.0,
#      'protein': 9.7,
#      'carbohydrate': 47.0,
#      'fibre': 3.0,
#      'avg_price': 5.5},
#     'sort': [5.5]},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '71823053',
#     '_score': None,
#     '_source': {'category': 'sweets',
#      'description': 'Belvita Milk And Cereal Biscuits 600G',
#      'ingredients': 'Cereals 69.6 % [<strong><strong>Wheat</strong></strong> Flour 47 %, Wholegrain Cereals 22.6 % (<strong>Oat</strong> Flakes 6.3 %, Wholegrain <strong><strong>Wheat</strong></strong> Flour 6.2 %, Whole Crushed Buckwheat 4.3 %, Wholegrain <strong>Barley</strong> Flour 2.8 %, Wholegrain <strong>Rye</strong> Flour 2 %, Wholegrain <strong>Spelt</strong> Flour 1 %)] Sugar Rapeseed Oil Bulking Agent (Polydextrose) Raising Agents (Sodium Hydrogen Carbonate, Disodium Diphosphate, Ammonium Hydrogen Carbonate) Whole <strong><strong>Milk</strong></strong> Powder 0.8 % (equivalent Whole <strong><strong>Milk</strong></strong> 7.1 %) Emulsifiers (E 472e, <strong>Soya</strong> Lecithin) Minerals (Magnesium Carbonates, Elemental Iron) Salt Flavourings Skimmed <strong>Milk</strong> Powder Vitamins [Vitamin E, Vitamin B1 (Thiamin)]',
#      'energy': 440.0,
#      'fat': 14.5,
#      'saturates': 1.4,
#      'salt': 0.83,
#      'sugars': 20.0,
#      'protein': 7.9,
#      'carbohydrate': 67.0,
#      'fibre': 6.5,
#      'avg_price': 5.17},
#     'sort': [5.17]},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '66993514',
#     '_score': None,
#     '_source': {'category': 'sweets',
#      'description': 'Thorntons Milk Chocolate Champagne Bottle',
#      'ingredients': 'Sugar Dried Whole <strong>Milk</strong> Cocoa Butter Cocoa Mass <strong>Milk</strong> Fat Emulsifier (<strong>Soya</strong> Lecithin) Fat Reduced Cocoa Powder Flavouring Milk Chocolate contains: Cocoa Solids 30% minimum, Milk Solids 20% minimum Dark Chocolate contains: Cocoa Solids 60% minimum',
#      'energy': 543.0,
#      'fat': 32.0,
#      'saturates': 20.0,
#      'salt': 0.24,
#      'sugars': 53.0,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 5.0},
#     'sort': [5.0]},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '77408236',
#     '_score': None,
#     '_source': {'category': 'sweets',
#      'description': 'Lindt Heart Milk Tin Chocolate 45G',
#      'ingredients': 'Sugar Cocoa Butter <strong>Whole Milk Powder</strong> Cocoa Mass <strong>Lactose</strong> <strong>Skimmed Milk Powder</strong> <strong>Milk Fat</strong> Emulsifier (<strong>Soya Lecithin</strong>) <strong>Barley Malt Extract</strong> Flavouring Cocoa Solids 32% min. Milk Solids 14% min',
#      'energy': 559.0,
#      'fat': 35.0,
#      'saturates': 22.0,
#      'salt': 0.22,
#      'sugars': 53.0,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 5.0},
#     'sort': [5.0]},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '77801951',
#     '_score': None,
#     '_source': {'category': 'sweets',
#      'description': 'Thorntons Classics Milk Dark And White 357G',
#      'ingredients': 'Sugar Dried Whole <strong>Milk</strong> Cocoa Butter Cocoa Mass Glucose Syrup Palm Kernel Oil Double Cream (<strong>Milk</strong>) Lactose (<strong>Milk</strong>) Humectant (Sorbitol) Coconut Oil (contains <strong>Soya</strong> Lecithin) Sweetened Condensed <strong><strong>Milk</strong></strong> (Whole <strong><strong>Milk</strong></strong>, Sugar) Butter (<strong>Milk</strong>) <strong>Almonds</strong> <strong>Hazelnuts</strong> <strong>Milk</strong> Fat Dried Skimmed <strong>Milk</strong> Fat Reduced Cocoa Powder Dextrose Emulsifiers (<strong>Soya</strong> Lecithin, E471, Sunflower Lecithin) Whole <strong>Milk</strong> Flavourings Raisins Raspberry Juice Concentrate Lemon Comminute Maize Starch Invert Sugar Syrup Freeze-Dried Instant Coffee Gelling Agent (Pectin) Acid (Citric Acid) Freeze-Dried Strawberry Powder Salt Palm Oil Orange Peel Glucose-Fructose Syrup Stabiliser (Invertase) Margarine (Palm Oil, Rapeseed Oil, Water, Flavouring, Vitamin A, Vitamin D) Colours (Anthocyanins, Carotenes) Rice Flour Dried Free Range <strong>Egg</strong> White Acidity Regulator (Sodium Citrate) Raising Agent (Sodium Bicarbonate) Cottonseed Oil <strong>Milk</strong> Protein May also contain: other <strong>Nuts</strong> Milk Chocolate contains: Cocoa Solids 30% minimum, Milk Solids 20% minimum Dark Chocolate contains: Cocoa Solids 60% minimum',
#      'energy': 494.0,
#      'fat': 25.0,
#      'saturates': 17.0,
#      'salt': 0.18,
#      'sugars': 57.0,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 5.0},
#     'sort': [5.0]},
#    {'_index': 'tesco',
#     '_type': '_doc',
#     '_id': '68173203',
#     '_score': None,
#     '_source': {'category': 'dairy',
#      'description': 'Just Milk Longlife Skimmed Milk 6X1l',
#      'ingredients': 'no_ingredients',
#      'energy': 32.0,
#      'fat': 0.1,
#      'saturates': 0.0,
#      'salt': 0.1,
#      'sugars': 4.8,
#      'protein': 0.0,
#      'carbohydrate': 0.0,
#      'fibre': 0.0,
#      'avg_price': 4.99},
#     'sort': [4.99]}]}}
